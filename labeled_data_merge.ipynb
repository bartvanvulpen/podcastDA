# %%
# import pandas as pd
# from os import listdir
# import os

# from sklearn.model_selection import train_test_split


# csv_files = listdir('labeled_datasets/separate_csv_files')

# if '.DS_Store' in csv_files:
#     csv_files.remove('.DS_Store')

    
# dfs = []  
# for filename in csv_files:
#     df = pd.read_csv('labeled_datasets/separate_csv_files/{}'.format(filename), sep='\t', )
#     df = df.drop('speaker_tag', 1)
#     dfs.append(df)
    
# # binary
# labeled_df_binary = pd.concat(dfs).reset_index(drop=True)
# labeled_df_binary.loc[labeled_df_binary['sentiment_score'] == 0.0, 'sentiment_score'] = 1
# labeled_df_binary.loc[labeled_df_binary['sentiment_score'] == -1.0, 'sentiment_score'] = 0
# labeled_df_binary.loc[labeled_df_binary['sentiment_score'] == 1.0, 'sentiment_score'] = 1

# # neutral included
# labeled_df_nonbinary = pd.concat(dfs).reset_index(drop=True)
# labeled_df_nonbinary.loc[labeled_df_nonbinary['sentiment_score'] == 0.0, 'sentiment_score'] = 0
# labeled_df_nonbinary.loc[labeled_df_nonbinary['sentiment_score'] == -1.0, 'sentiment_score'] = -1
# labeled_df_nonbinary.loc[labeled_df_nonbinary['sentiment_score'] == 1.0, 'sentiment_score'] = 1


# # to csv
# labeled_df_binary.to_csv('labeled_datasets/binary/binary_full.csv', sep='\t', index=False)
# labeled_df_nonbinary.to_csv('labeled_datasets/nonbinary/nonbinary_full.csv', sep='\t', index=False)


# # create train and test set for both non binary

# nonbin_train, nonbin_val = train_test_split(labeled_df_nonbinary, test_size=0.3)
# nonbin_train.to_csv('labeled_datasets/nonbinary/nonbinary_train.csv', sep='\t', index=False)
# nonbin_val.to_csv('labeled_datasets/nonbinary/nonbinary_val.csv', sep='\t', index=False)

# nonbin_train.loc[nonbin_train['sentiment_score'] == 0.0, 'sentiment_score'] = 1
# nonbin_train.loc[nonbin_train['sentiment_score'] == -1.0, 'sentiment_score'] = 0
# nonbin_train.loc[nonbin_train['sentiment_score'] == 1.0, 'sentiment_score'] = 1

# nonbin_val.loc[nonbin_val['sentiment_score'] == 0.0, 'sentiment_score'] = 1
# nonbin_val.loc[nonbin_val['sentiment_score'] == -1.0, 'sentiment_score'] = 0
# nonbin_val.loc[nonbin_val['sentiment_score'] == 1.0, 'sentiment_score'] = 1

# nonbin_train.to_csv('labeled_datasets/binary/binary_train.csv', sep='\t', index=False)
# nonbin_val.to_csv('labeled_datasets/binary/binary_val.csv', sep='\t', index=False)



# # # to csv
# # bin_train.to_csv('labeled_datasets/binary/binary_train.csv', sep='\t', index=False)
# # bin_val.to_csv('labeled_datasets/binary/binary_val.csv', sep='\t', index=False)

# # nonbin_train.to_csv('labeled_datasets/nonbinary/nonbinary_train.csv', sep='\t', index=False)
# # nonbin_val.to_csv('labeled_datasets/nonbinary/nonbinary_val.csv', sep='\t', index=False)
